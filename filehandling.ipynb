# %%
import pandas as pd
s = pd.Series(["Physics", "Chemistry", "Biology", "Maths"], index=[1, 2, 3, 4])
print(s)
# Out:
# 1      Physics
# 2    Chemistry
# 3      Biology
# 4        Maths
# dtype: str

# %%
import numpy as np
import pandas as pd
pd.DataFrame(np.random.rand(3, 2), columns=['A', 'B'], index=dates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 pd.DataFrame(np.random.rand(3, 2), columns=['A', 'B'], index=dates)
#
# NameError: name 'dates' is not defined

# %%
# creating a DataFrame
import pandas as pd
name=pd.series([{Name: 'John', 'Age': 25}, {'Name': 'Alice', 'Age': 30}, {'Name': 'Bob', 'Age': 35}])
